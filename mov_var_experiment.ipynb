# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from misc_utils import PokemonEntity, BasicPkmnLogic, load_pokemon
from pathlib import Path

# %%
# Out:
# ['C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv', '', 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages', 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\Pythonwin', '/', '../', '../', '../', '../']
# {'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip': None, 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\DLLs': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\DLLs'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\encodings': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\encodings'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32\\lib': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\win32\\lib'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\Pythonwin': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\Pythonwin'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\experiments': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\experiments'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\importlib': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\importlib'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\re': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\re'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\urllib': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\urllib'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\ipykernel': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\ipykernel'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\collections': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\collections'), 'C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json': FileFinder('C:\\Users\\zahdehv\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\json'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\jupyter_client': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\jupyter_client'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\jupyter_client\\asynchronous': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\jupyter_client\\asynchronous'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\zmq': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\zmq'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\zmq\\backend': FileFinder('c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\zmq\\backend'), 'c:\\Users\\zahdehv\\Documents\\GITHUB Media\\pokemon-python\\.venv\\Lib\\site-packages\\zmq\\backend\\cython': FileFinder('c:\\Users\\zahdehv\\Documents ...
# DLLs

# %%
from misc_utils import PokemonEntity
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from misc_utils import PokemonEntity
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\misc_utils.py:1
# ----> 1 from pokemon import PokemonEntity
#       2 #created to resolve pickle conflicts
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\pokemon.py:7
#       5 from pureples.shared.visualize import draw_net
#       6 from pureples.es_hyperneat.es_hyperneat import ESNetwork
# ----> 7 import sim.sim as sim
#       8 from tools.pick_six import generate_team_pok
#       9 from sim.structs import Pokemon
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\sim\sim.py:17
#       1 '''
#       2 Nicolas Lindbloom-Airey
#       3
#    (...)
#      14 the state of the battle. No info is hidden.
#      15 '''
#      16 import heapq
# ---> 17 from sim.player import *
#      20 def new_battle(format_str:str, name1:str, team1:List[PokemonSet],
#      21                 name2:str, team2:List[PokemonSet], debug:bool) -> Battle:
#      22     return Battle(format_str, name1, team1, name2, team2, debug)
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\sim\player.py:15
#       1 '''
#       2 Nicolas Lindbloom-Airey
#       3
#    (...)
#      12     pokemon_left
#      13 '''
#      14 import sys
# ---> 15 from sim.pokemon import *
#      17 def switch(B:Battle, T:Player, user:Pokemon, position:int, player_name) -> bool:
#      18     '''
#      19     switch the active pokemon to the pokemon in index: position
#      20
#    (...)
#      24     RETURNS true if we were able to do the switch, false if we couldn't
#      25     '''
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\sim\pokemon.py:29
#       1 '''
#       2 Nicolas Lindbloom-Airey
#       3
#    (...)
#      26     mega_evolve
#      27 '''
#      28 import random
# ---> 29 from sim.structs import *
#      32 def get_attack(P:Pokemon, weather:str, crit:bool=False) -> float:
#      33     '''
#      34     Returns modified attack stat.
#      35     Requires info about weather.
#      36     '''
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\sim\structs.py:34
#      32 from dataclasses import field
#      33 from dataclasses import InitVar
# ---> 34 from data import dex
#      35 import math
#      38 # packed str format:
#      39 # name|species|item|ability|moves|nature|evs|gender|ivs|shiny|level|happiness]
#      40 # we will not allow empty fields
#
# File c:\Users\zahdehv\Documents\GITHUB Media\pokemon-python\experiments\..\data\dex.py:12
#       5 import re
#       8 #this module is for searching the dex, aka all the game data
#       9
#      10 #missing statuses, scripts, rulesets(formats), formatsdata( event pokemon and thespeed move_dex), aliases
# ---> 12 with open('data/abilities.json') as f:
#      13     abilities_raw_data = json.load(f)
#      14 with open('data/formats.json') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/abilities.json'

# %%
def update_used_moves(pkmn, move):
    if move in pkmn.used_moves:
        pkmn.used_moves[move] += 1
    else:
        pkmn.used_moves[move] = 1

def battle_pokemons(pokemon1: PokemonEntity, pokemon2: PokemonEntity):
    battle_logic = BasicPkmnLogic()
    battle_logic.manual_battle_create(pokemon1, pokemon2)
    
    while not battle_logic.manual_battle.ended:
        if battle_logic.manual_battle.turn > 500:
            break
        choice1 = pokemon1.ask_for_choice(battle_logic.manual_battle.p1.active_pokemon[0], 
                                          battle_logic.manual_battle.p2.active_pokemon[0])
        battle_logic.manual_battle_do_turn(pokemon1, pokemon2, choice1)
        
        # Actualizar movimientos usados
        if 0 <= choice1 < 4:
            move = pokemon1.entity[0].moves[choice1]
            update_used_moves(pokemon1, move)
    
    winner = pokemon1 if battle_logic.manual_battle.winner == 'p1' else pokemon2
    loser = pokemon2 if battle_logic.manual_battle.winner == 'p1' else pokemon1
    
    return winner, loser

def tournament(pokemons):
    for pok in pokemons:
        pok: PokemonEntity
        print("pokemon", pok.entity[0].species)
        for i in range(30):
            foe = np.random.choice(pokemons)
            winner, loser = battle_pokemons(pok, foe)
            winner.won_battles += 1
            winner.total_battles += 1
            loser.total_battles += 1

# %%
def run_experiment(path):
    pokemons = []  # Crear 50 Pokémon para el experimento
    for pat in Path(f"./{path}/pkmns/").iterdir():
        pk = load_pokemon(pat)
        pk.lvl = 100
        pk.entity[0].level = 100
        pk.won_battles = 0
        pk.total_battles = 0
        pk.used_moves = {}
        pokemons.append(pk)
        
    tournament(pokemons)

    move_usage_data = np.array([len(p.used_moves) for p in pokemons])
    print(move_usage_data)

    observed_distribution = np.bincount(move_usage_data, minlength=5) / len(pokemons)

    expected_distribution = np.ones(5) / 5

    ks_statistic, p_value = stats.kstest(observed_distribution, stats.uniform(loc=0, scale=5).cdf)

    entropy = stats.entropy(observed_distribution)

    mean_moves = np.mean(move_usage_data)
    var_moves = np.var(move_usage_data)

    print(f"Resultados para Exp move usage")
    print(f"D de Kolmogorov-Smirnov: {ks_statistic:.4f}")
    print(f"p-valor: {p_value:.4f}")
    print(f"Entropía de Shannon: {entropy:.4f}")
    print(f"Promedio de movimientos usados: {mean_moves:.2f}")
    print(f"Varianza de movimientos usados: {var_moves:.2f}")

    # Visualización
    plt.figure(figsize=(10, 6))
    plt.bar(range(5), observed_distribution, alpha=0.8, label='Observado')
    plt.plot(range(5), expected_distribution, 'r--', label='Esperado (Uniforme)')
    plt.title(f'Distribución de Uso de Movimientos - {"Exp I move usage"}')
    plt.xlabel('Número de Movimientos Usados')
    plt.ylabel('Frecuencia Relativa')
    plt.legend()
    plt.savefig(f'./{path}/{"Exp I move usage".lower().replace(" ", "_")}_distribution.png')
    plt.close()

    # Guardar los datos de cada Pokémon
    for i, pokemon in enumerate(pokemons):
        with open(f'./{path}/results/pokemon_data_{i}.txt', 'w') as f:
            f.write(f"Especie: {pokemon.entity[0].species}\n")
            f.write(f"Batallas ganadas: {pokemon.won_battles}/{pokemon.total_battles}\n")
            f.write(f"Nivel: {pokemon.lvl}\n")
            f.write("Movimientos usados:\n")
            for move, count in pokemon.used_moves.items():
                f.write(f"  {move}: {count} veces\n")
            f.write(f"Total de movimientos diferentes usados: {len(pokemon.used_moves)}\n")

# %%
run_experiment("experiments/moves/experiment_i")
run_experiment("experiments/moves/experiment_i")
